# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Load the post harmo data
df_post = pd.read_csv('/home/tanurima/germany/brain_age_parcels/kunal/Filtered_Datasets/CamCAN/Test_CamCAN_m1_150.csv')

# Create scatter plot for post harmo
plt.figure(figsize=(8, 6))
plt.scatter(df_post['Actual_Age'], df_post['Predicted_Age'], color='blue', alpha=0.7)
plt.title('Post Harmo m1(CamCAN): Actual Age vs Predicted Age')
plt.xlabel('Actual Age')
plt.ylabel('Predicted Age')
plt.grid(True)
plt.show()
plt.savefig('/home/tanurima/germany/brain_age_parcels/kunal/Filtered_Datasets/CamCAN/Test_CamCAN_m1.png')

# %%
from sklearn.metrics import r2_score
# Calculate R² for Post Harmo
r2_post = r2_score(df_post['Actual_Age'], df_post['Predicted_Age'])
print(f'R² value m1(Post Harmo): {r2_post:.4f}')
# Out:
# R² value m1(Post Harmo): 0.6204

# %%
# Calculate Pearson correlation for Post Harmo
corr_post = np.corrcoef(df_post['Actual_Age'], df_post['Predicted_Age'])[0, 1]
print(f'Pearson Correlation Coefficient m1(Post Harmo): {corr_post:.4f}')
# Out:
# Pearson Correlation Coefficient m1(Post Harmo): 0.9262

# %%
# Load the post harmo data
df_post = pd.read_csv('/home/tanurima/germany/brain_age_parcels/kunal/Filtered_Datasets/CamCAN/Test_CamCAN_m2_150.csv')

# Create scatter plot for post harmo
plt.figure(figsize=(8, 6))
plt.scatter(df_post['Actual_Age'], df_post['Predicted_Age'], color='navy', alpha=0.7)
plt.title('Post Harmo m2(CamCAN): Actual Age vs Predicted Age')
plt.xlabel('Actual Age')
plt.ylabel('Predicted Age')
plt.grid(True)
plt.show()
plt.savefig('/home/tanurima/germany/brain_age_parcels/kunal/Filtered_Datasets/CamCAN/Test_CamCAN_m2.png')

# %%
from sklearn.metrics import r2_score
# Calculate R² for Post Harmo
r2_post = r2_score(df_post['Actual_Age'], df_post['Predicted_Age'])
print(f'R² value m2(Post Harmo): {r2_post:.4f}')
# Out:
# R² value m2(Post Harmo): 0.5687

# %%
# Calculate Pearson correlation for Post Harmo
corr_post = np.corrcoef(df_post['Actual_Age'], df_post['Predicted_Age'])[0, 1]
print(f'Pearson Correlation Coefficient m2(Post Harmo): {corr_post:.4f}')
# Out:
# Pearson Correlation Coefficient m2(Post Harmo): 0.9285

# %%
# Load the pre harmo data
df_pre = pd.read_csv('/home/tanurima/germany/brain_age_parcels/kunal/Filtered_Datasets/CamCAN/Test_CamCAN_150.csv')

# Create scatter plot for pre harmo
plt.figure(figsize=(8, 6))
plt.scatter(df_pre['Actual_Age'], df_pre['Predicted_Age'], color='green', alpha=0.7)
plt.title('Pre Harmo(CamCAN): Actual Age vs Predicted Age')
plt.xlabel('Actual Age')
plt.ylabel('Predicted Age')
plt.grid(True)
plt.show()
plt.savefig('/home/tanurima/germany/brain_age_parcels/kunal/Filtered_Datasets/CamCAN/Test_CamCAN.png')

# %%
# Calculate R² for Pre Harmo
r2_pre = r2_score(df_pre['Actual_Age'], df_pre['Predicted_Age'])
print(f'R² value (Pre Harmo): {r2_pre:.4f}')
# Out:
# R² value (Pre Harmo): 0.4619

# %%
# Calculate Pearson correlation for Pre Harmo
corr_pre = np.corrcoef(df_pre['Actual_Age'], df_pre['Predicted_Age'])[0, 1]
print(f'Pearson Correlation Coefficient (Pre Harmo): {corr_pre:.4f}')
# Out:
# Pearson Correlation Coefficient (Pre Harmo): 0.9326
